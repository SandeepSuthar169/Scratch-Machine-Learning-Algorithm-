# %% [markdown]
# ## 1.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_regression

# %%
x, y = make_regression(n_samples=4,
                      n_features=1,
                      n_informative= 4,
                      n_targets=1,
                      noise=80)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg =LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X = True,
                 fit_intercept=True,
                 n_jobs = None)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-63.61685735])

# %%
reg.intercept_
# Out:
# -14.591660858389282

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x), color="black")

# %%
b=100
m=-63.61685
lr=0.01
epoch=1000

for i in range(epoch):
  loss_slop =-2*np.sum(y-m*x.ravel() - b)
  b =b - (lr * loss_slop)

  y_pred = m * x + b

  plt.plot(x,y_pred)

plt.scatter(x,y)

# %% [markdown]
# ## 2.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
x, y = make_regression(n_samples=100,
                      n_features=1,
                      n_informative= 4,
                      n_targets=1,
                      noise=5,
                       random_state=13)

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.74724142]
# -0.6782681417310259

# %%
y_pred = lr.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9663149861351787

# %%
class GDregression:

  def __init__(self, learning_rate, epochs):
    self.m =100
    self.b = 100
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self, x, y):
    for  i in range(self.epochs):
      loss_slpo_b = -2*np.sum(y - self.m*x.ravel() - self.b)
      loss_slpo_m = -2*np.sum((y - self.m*x.ravel() - self.b)*x.ravel())

      self.b = self.b - (self.lr*loss_slpo_b)
      self.m = self.m - (self.lr*loss_slpo_m)

    print(self.m, self.b)

  def predict(self, x):
    return self.m*x+self.b

# %%
gb = GDregression(0.01, 500)
gb.fit(x_train, y_train)
# Out:
# 27.747241416131743 -0.6782681417310253

# %%
y_pred = gb.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9663149861351787
